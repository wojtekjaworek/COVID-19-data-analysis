# %% [markdown]
# # COVID-19 Data Visualization

# %% [markdown]
# ### Using Pandas, Matplotlib.pyplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates

# %% [markdown]
# #### specify data url, select country

# %%
# data_url = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'
data_url = 'https://covid19.who.int/WHO-COVID-19-global-table-data.csv'
country = 'Russia'

# %% [markdown]
# ### Read and clean data

# %%
data = pd.read_csv(data_url, delimiter=',', header=0, quotechar='"', encoding="utf8")
data.head(100)
# Out:
#                                      Name  WHO Region  \
# Global                                NaN   259502031
# United States of America         Americas    47802459
# India                     South-East Asia    34555431
# Brazil                           Americas    22043112
# The United Kingdom                 Europe    10021501
# ...                                   ...         ...
# Australia                 Western Pacific      203650
# Albania                            Europe      198292
# Botswana                           Africa      194909
# Uzbekistan                         Europe      192381
# Puerto Rico                      Americas      187718
#
#                           Cases - cumulative total  \
# Global                                 3329.279458
# United States of America              14441.715000
# India                                  2504.009000
# Brazil                                10370.330000
# The United Kingdom                    14762.249000
# ...                                            ...
# Australia                               798.631000
# Albania                                6890.402000
# Botswana                               8288.262000
# Uzbekistan                              574.800000
# Puerto Rico                            6561.609000
#
#                           Cases - cumulative total per 100000 population  \
# Global                                                           3980811
# United States of America                                          666617
# India                                                              65808
# Brazil                                                             65451
# The United Kingdom                                                299581
# ...                                                                  ...
# Australia                                                           9531
# Albania                                                             3271
# Botswana                                                             464
# Uzbekistan                                                          1531
# Puerto Rico                                                          813
#
#                           Cases - newly reported in last 7 days  \
# Global                                                51.071786
# United States of America                             201.393000
# India                                                  4.769000
# Brazil                                                30.792000
# The United Kingdom                                   441.300000
# ...                                                         ...
# Australia                                             37.377000
# Albania                                              113.663000
# Botswana                                              19.731000
# Uzbekistan                                             4.574000
# Puerto Rico                                           28.418000
#
#                           Cases - newly reported in last 7 days per 100000 population  \
# Global                                                               611528
# United States of America                                             100455
# India                                                                 10549
# Brazil                                                                12930
# The United Kingdom                                                    46654
# ...                                                                     ...
# Australia                                                              1555
# Albania                                                                 516
# Botswana                                                                257
# Uzbekistan                                                              206
# Puerto Rico                                                             137
#
#                           Cases - newly reported in last 24 hours  \
# Global                                                    5183003
# United States of America                                   771529
# India                                                      467468
# Brazil                                                     613339
# The United Kingdom                                         144433
# ...                                                           ...
# Australia                                                    1978
# Albania                                                      3068
# Botswana                                                     2416
# Uzbekistan                                                   1392
# Puerto Rico                                                  3266
#
#                           Deaths - cumulative total  \
# Global                                      66.4953
# United States of America                   233.0880
# India                                       33.8740
# Brazil                                     288.5490
# The United Kingdom                         212.7580
# ...                                             ...
# Australia                                    7.7570
# Albania                                    106.6090
# Botswana                                   102.7370
# Uzbekistan                                   4.1590
# Puerto Rico                                114.1620
#
#                           Deaths - cumulative total per 100000 population  \
# Global                                                              52000
# United States of America                                            10338
# India                                                                2386
# Brazil                                                               1488
# The United Kingdom                                                    874
# ...                                                                   ...
# Australia                                                              56
# Albania                                                                46
# Botswana                                                                0
# Uzbekistan                                                             22
# Puerto Rico                                                             7
#
#                           Deaths - newly reported in last 7 days  \
# Global                                                  0.667134
# United States of America                                3.123000
# India                                                   0.173000
# Brazil                                                  0.700000
# The United Kingdom                                      1.287000
# ...                                                          ...
# Australia                                               0.220000
# Albania                                                 1.598000
# Botswana                                                0.000000
# Uzbekistan                                              0.066000
# Puerto Rico                                             0.245000
#
#                           Deaths - newly reported in last 7 days per 100000 population  \
# Global                                                                 7881
# United States of America                                               1367
# India                                                                   488
# Brazil                                                                  273
# The United Kingdom                                                      147
# ...                                                                     ...
# Australia                                                                 5
# Albania                                                                   5
# Botswana                                                                  0
# Uzbekistan                                                                3
# Puerto Rico                                                               0
#
#                           Deaths - newly reported in last 24 hours
# Global                                                         NaN
# United States of America                                       NaN
# India                                                          NaN
# Brazil                                                         NaN
# The United Kingdom                                             NaN
# ...                                                            ...
# Australia                                                      NaN
# Albania                                                        NaN
# Botswana                                                       NaN
# Uzbekistan                                                     NaN
# Puerto Rico                                                    NaN
#
# [100 rows x 12 columns]

# %%
countries = data[['Name']]
countries = countries.drop_duplicates(subset = ['Name'], keep='first')

# %%
data = data[data['Name'] == country]
data.head()
# Out:
# Empty DataFrame
# Columns: [Name, WHO Region, Cases - cumulative total, Cases - cumulative total per 100000 population, Cases - newly reported in last 7 days, Cases - newly reported in last 7 days per 100000 population, Cases - newly reported in last 24 hours, Deaths - cumulative total, Deaths - cumulative total per 100000 population, Deaths - newly reported in last 7 days, Deaths - newly reported in last 7 days per 100000 population, Deaths - newly reported in last 24 hours, Transmission Classification]
# Index: []

# %% [markdown]
# ### Create plots

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(20, 12))



ax1.plot(data['date'], data['new_cases'])
# Set title and labels for axes
ax1.set(xlabel="Date (YYYY-MM)", ylabel="New cases", title="New cases in " + country)
ax1.grid()
ax1.fill_between(data['date'], data['new_cases'], color=(185/255,206/255,255/255,255/255))
ax1.set_ylim(ax1.get_ylim())




ax2.plot(data['date'], data['new_deaths'], color='black')
# Set title and labels for axes
ax2.set(xlabel="Date (YYYY-MM)", ylabel="New cases and deaths", title="New deaths in "+country)
ax2.grid()
ax2.fill_between(data['date'], data['new_deaths'], color=(0/255,0/255,0/255,50/255))
ax2.set_ylim(ax2.get_ylim())




ax3.plot(data['date'], data['total_cases'])
# Set title and labels for axes
ax3.set(xlabel="Date (YYYY-MM)", ylabel="Cumulative cases", title="Cumulative cases in "+country)
ax3.grid()
ax3.fill_between(data['date'], data['total_cases'], color=(185/255,206/255,255/255,255/255))
ax3.set_ylim(ax3.get_ylim())




ax4.plot(data['date'], data['total_deaths'], color='black')
# Set title and labels for axes
ax4.set(xlabel="Date (YYYY-MM)", ylabel="Cumulative deaths", title="Cumulative deaths in "+country)
ax4.grid()
ax4.fill_between(data['date'], data['total_deaths'], color=(0/255,0/255,0/255,50/255))
ax4.set_ylim(ax4.get_ylim())

plt.show()
